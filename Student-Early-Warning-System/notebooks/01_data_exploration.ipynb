# %%
import pandas as pd

df = pd.read_csv("../data/raw/students_performance.csv")
df.head()

# %%
print("Shape:", df.shape)
df.info()

# %%
df.isnull().sum()

# %%
df['GradeClass'].value_counts()

# %%
df.describe()
